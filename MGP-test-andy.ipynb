# %%
import pandas as pd

# %%
#covid_df = pd.read_csv('https://docs.google.com/spreadsheets/d/1r82MDoJboLedKOofx-JZlvdWMu8GRSL8oDZfCo0w2xM/edit#gid=0',error_bad_lines=False)

# %%
sheet_url = "https://docs.google.com/spreadsheets/d/1S0UyuuG-rG7W3SmLSCc-KLYd_kpdifQDaZ7TrSAu0uY/edit#gid=0"
url_1 = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
pd.read_csv(url_1)
# Out:
#     Aciertos  Errores                              Tiempo entre aciertos  \
# 0          5        8  0.9862728,0.6840477,0.7080059,0.9909058,1.0123...
# 1          8        4  1.129272,4.134277,0.6556396,1.152466,0.5959473...
# 2          8        4  1.129272,4.134277,0.6556396,1.152466,0.5959473...
# 3          8        1  1.35927,0.6195278,0.6016436,0.7307382,1.692197...
# 4          8        3  0.7023163,1.292572,1.13636,0.6447601,1.551178,...
# 5          8        3                                                  -
# 6          5        0                                                  -
# 7          5        0                                                  -
# 8          5        0     0.9203007,0.7203419,1.055336,0.6878939,2.59999
# 9          5        0   0.6394043,0.5525665,0.7123413,0.6951599,1.279831
# 10         5        1    0.5517502,0.6628666,0.9130974,2.347412,1.512041
# 11        10        0  0.7519531,0.7911491,0.7079887,1.665054,0.98205...
# ...
